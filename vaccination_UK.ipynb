# %%
# import packages
import requests
import pandas as pd
from urllib.parse import quote
import time

# state base/headers
BASE = "https://api.ukhsa-dashboard.data.gov.uk"
HEADERS = {"Accept": "application/json"}

# %%
# 2024 test
import requests
import pandas as pd
from urllib.parse import quote
import time

BASE = "https://api.ukhsa-dashboard.data.gov.uk"
HEADERS = {"Accept": "application/json"}

TARGET_YEAR = 2024

geo_url = (
    f"{BASE}/themes/immunisation/sub_themes/childhood-vaccines/"
    f"topics/MMR1/geography_types/Upper%20Tier%20Local%20Authority/geographies"
)

geos = requests.get(geo_url, headers=HEADERS).json()
area_names = [g["name"] for g in geos]

vaccines = {
    "MMR1": "MMR1_coverage_coverageByYear",
    "MMR2": "MMR2_coverage_coverageByYear"
}

all_rows = []

for vaccine, metric_name in vaccines.items():
    print(f"Pulling {vaccine}...")
    
    for i, area in enumerate(area_names):
        print(f"{vaccine} | {i+1}/{len(area_names)} | {area}")
        
        encoded_area = quote(area)
        
        url = (
            f"{BASE}/themes/immunisation/sub_themes/childhood-vaccines/"
            f"topics/{vaccine}/geography_types/Upper%20Tier%20Local%20Authority/"
            f"geographies/{encoded_area}/metrics/{metric_name}"
        )
        
        while url:
            r = requests.get(url, headers=HEADERS)
            js = r.json()
            
            for record in js["results"]:
                if record["year"] == TARGET_YEAR:
                    all_rows.append({
                        "area_code": record["geography_code"],
                        "area_name": record["geography"],
                        "year": record["year"],
                        "vaccine": vaccine,
                        "age_stratum": record["stratum"],
                        "coverage": record["metric_value"]
                    })
            
            url = js["next"]
        
        time.sleep(0.1)  # be polite to API

df = pd.DataFrame(all_rows)

df.to_csv("mmr_utla_2024_only.csv", index=False)

print("Done.")
# Out:
# Pulling MMR1...
# MMR1 | 1/152 | Barking and Dagenham
# MMR1 | 2/152 | Barnet
# MMR1 | 3/152 | Barnsley
# MMR1 | 4/152 | Bath and North East Somerset
# MMR1 | 5/152 | Bedford
# MMR1 | 6/152 | Bexley
# MMR1 | 7/152 | Birmingham
# MMR1 | 8/152 | Blackburn with Darwen
# MMR1 | 9/152 | Blackpool
# MMR1 | 10/152 | Bolton
# MMR1 | 11/152 | Bournemouth, Christchurch and Poole
# MMR1 | 12/152 | Bracknell Forest
# MMR1 | 13/152 | Bradford
# MMR1 | 14/152 | Brent
# MMR1 | 15/152 | Brighton and Hove
# MMR1 | 16/152 | Bristol, City of
# MMR1 | 17/152 | Bromley
# MMR1 | 18/152 | Buckinghamshire
# MMR1 | 19/152 | Bury
# MMR1 | 20/152 | Calderdale
# MMR1 | 21/152 | Cambridgeshire
# MMR1 | 22/152 | Camden
# MMR1 | 23/152 | Central Bedfordshire
# MMR1 | 24/152 | Cheshire East
# MMR1 | 25/152 | Cheshire West and Chester
# MMR1 | 26/152 | Cornwall
# MMR1 | 27/152 | County Durham
# MMR1 | 28/152 | Coventry
# MMR1 | 29/152 | Croydon
# MMR1 | 30/152 | Cumberland
# MMR1 | 31/152 | Darlington
# MMR1 | 32/152 | Derby
# MMR1 | 33/152 | Derbyshire
# MMR1 | 34/152 | Devon
# MMR1 | 35/152 | Doncaster
# MMR1 | 36/152 | Dorset
# MMR1 | 37/152 | Dudley
# MMR1 | 38/152 | Ealing
# MMR1 | 39/152 | East Riding of Yorkshire
# MMR1 | 40/152 | East Sussex
# MMR1 | 41/152 | Enfield
# MMR1 | 42/152 | Essex
# MMR1 | 43/152 | Gateshead
# MMR1 | 44/152 | Gloucestershire
# MMR1 | 45/152 | Greenwich
# MMR1 | 46/152 | Hackney
# MMR1 | 47/152 | Halton
# MMR1 | 48/152 | Hammersmith and Fulham
# MMR1 | 49/152 | Hampshire
# MMR1 | 50/152 | Haringey
# MMR1 | 51/152 | Harrow
# MMR1 | 52/152 | Hartlepool
# MMR1 | 53/152 | Havering
# MMR1 | 54/152 | Herefordshire, County of
# MMR1 | 55/152 | Hertfordshire
# MMR1 | 56/152 | Hillingdon
# MMR1 | 57/152 | Hounslow
# MMR1 | 58/152 | Isle of Wight
# MMR1 | 59/152 | Islington
# MMR1 | 60/152 | Kensington and Chelsea
# MMR1 | 61/152 | Kent
# MMR1 | 62/152 | Kingston upon Hull, City of
# MMR1 | 63/152 | Kingston upon Thames
# MMR1 | 64/152 | Kirklees
# MMR1 | 65/152 | Knowsley
# MMR1 | 66/152 | Lambeth
# MMR1 | 67/152 | Lancashire
# MMR1 | 68/152 | Leeds
# MMR1 | 69/152 | Leicester
# MMR1 | 70/152 | Leicestershire
# MMR1 | 71/152 | Lewisham
# MMR1 | 72/152 | Lincolnshire
# MMR1 | 73/152 | Liverpool
# MMR1 | 74/152 | Luton
# MMR1 | 75/152 | Manchester
# MMR1 | 76/152 | Medway
# MMR1 | 77/152 | Merton
# MMR1 | 78/152 | Middlesbrough
# MMR1 | 79/152 | Milton Keynes
# MMR1 | 80/152 | Newcastle upon Tyne
# MMR1 | 81/152 | Newham
# MMR1 | 82/152 | Norfolk
# MMR1 | 83/152 | Northamptonshire
# MMR1 | 84/152 | North East Lincolnshire
# MMR1 | 85/152 | North Lincolnshire
# MMR1 | 86/152 | North Northamptonshire
# MMR1 | 87/152 | North Somerset
# MMR1 | 88/152 | North Tyneside
# MMR1 | 89/152 | Northumberland
# MMR1 | 90/152 | North Yorkshire
# MMR1 | 91/152 | Nottingham
# MMR1 | 92/152 | Nottinghamshire
# MMR1 | 93/152 | Oldham
# MMR1 | 94/152 | Oxfordshire
# MMR1 | 95/152 | Peterborough
# MMR1 | 96/152 | Plymouth
# MMR1 | 97/152 | Poole
# MMR1 | 98/152 | Portsmouth
# MMR1 | 99/152 | Reading
# MMR1 | 100/152 | Redbridge
# MMR1 | 101/152 | Redcar and Cleveland
# MMR1 | 102/152 | Richmond upon Thames
# MMR1 | 103/152 | Rochdale
# MMR1 | 104/152 | Rotherham
# MMR1 | 105/152 | Salford
# MMR1 | 106/152 | Sandwell
# MMR1 | 107/152 | Sefton
# MMR1 | 108/152 | Sheffield
# MMR1 | 109/152 | Shropshire
# MMR1 | 110/152 | Slough
# MMR1 | 111/152 | Solihull
# MMR1 | 112/152 | Somerset
# MMR1 | 113/152 | Southampton
# MMR2 | 118/152 | Staffordshire
# MMR2 | 119/152 | St. Helens
# MMR2 | 120/152 | Stockport
# MMR2 | 121/152 | Stockton-on-Tees
# MMR2 | 122/152 | Stoke-on-Trent
# MMR2 | 123/152 | Suffolk
# MMR2 | 124/152 | Sunderland
# MMR2 | 125/152 | Surrey
# MMR2 | 126/152 | Sutton
# MMR2 | 127/152 | Swindon
# MMR2 | 128/152 | Tameside
# MMR2 | 129/152 | Telford and Wrekin
# MMR2 | 130/152 | Thurrock
# MMR2 | 131/152 | Torbay
# MMR2 | 132/152 | Tower Hamlets
# MMR2 | 133/152 | Trafford
# MMR2 | 134/152 | Wakefield
# MMR2 | 135/152 | Walsall
# MMR2 | 136/152 | Waltham Forest
# MMR2 | 137/152 | Wandsworth
# MMR2 | 138/152 | Warrington
# MMR2 | 139/152 | Warwickshire
# MMR2 | 140/152 | West Berkshire
# MMR2 | 141/152 | Westminster
# MMR2 | 142/152 | Westmorland and Furness
# MMR2 | 143/152 | West Northamptonshire
# MMR2 | 144/152 | West Sussex
# MMR2 | 145/152 | Wigan
# MMR2 | 146/152 | Wiltshire
# MMR2 | 147/152 | Windsor and Maidenhead
# MMR2 | 148/152 | Wirral
# MMR2 | 149/152 | Wokingham
# MMR2 | 150/152 | Wolverhampton
# MMR2 | 151/152 | Worcestershire
# MMR2 | 152/152 | York
# Done.

# %%
# run across dataset
START_YEAR = 2014
END_YEAR = 2025

# get all upper local authority names
geo_url = (
    f"{BASE}/themes/immunisation/sub_themes/childhood-vaccines/"
    f"topics/MMR1/geography_types/Upper%20Tier%20Local%20Authority/geographies"
)

geos = requests.get(geo_url, headers=HEADERS).json()
area_names = [g["name"] for g in geos]

vaccines = {
    "MMR1": "MMR1_coverage_coverageByYear",
    "MMR2": "MMR2_coverage_coverageByYear"
}

all_rows = []

# function for calling 
for vaccine, metric_name in vaccines.items():
    print(f"\nPulling {vaccine}...")
    
    for i, area in enumerate(area_names):
        print(f"{vaccine} | {i+1}/{len(area_names)} | {area}")
        
        encoded_area = quote(area)
        
        url = (
            f"{BASE}/themes/immunisation/sub_themes/childhood-vaccines/"
            f"topics/{vaccine}/geography_types/Upper%20Tier%20Local%20Authority/"
            f"geographies/{encoded_area}/metrics/{metric_name}"
        )
        
        while url:
            r = requests.get(url, headers=HEADERS)
            js = r.json()
            
            for record in js["results"]:
                
                if START_YEAR <= record["year"] <= END_YEAR:
                    
                    # keeping required strata
                    if vaccine == "MMR1" and record["stratum"] in ["24m", "5y"]:
                        all_rows.append({
                            "area_code": record["geography_code"],
                            "area_name": record["geography"],
                            "year": record["year"],
                            "variable": f"MMR1_{record['stratum']}",
                            "coverage": record["metric_value"]
                        })
                    
                    if vaccine == "MMR2" and record["stratum"] == "5y":
                        all_rows.append({
                            "area_code": record["geography_code"],
                            "area_name": record["geography"],
                            "year": record["year"],
                            "variable": "MMR2_5y",
                            "coverage": record["metric_value"]
                        })
            
            url = js["next"]
        
        time.sleep(0.1)  

# convert to df
df_long = pd.DataFrame(all_rows)

# wide pivot
df_wide = (
    df_long
    .pivot_table(
        index=["area_code", "area_name", "year"],
        columns="variable",
        values="coverage"
    )
    .reset_index()
)

df_wide = df_wide.sort_values(["area_name", "year"])

# export
df_wide.to_csv("mmr_utla_2013_2025_wide.csv", index=False)

print("\nDone.")
# Out:
# Pulling MMR1...
# MMR1 | 1/152 | Barking and Dagenham
# MMR1 | 2/152 | Barnet
# MMR1 | 3/152 | Barnsley
# MMR1 | 4/152 | Bath and North East Somerset
# MMR1 | 5/152 | Bedford
# MMR1 | 6/152 | Bexley
# MMR1 | 7/152 | Birmingham
# MMR1 | 8/152 | Blackburn with Darwen
# MMR1 | 9/152 | Blackpool
# MMR1 | 10/152 | Bolton
# MMR1 | 11/152 | Bournemouth, Christchurch and Poole
# MMR1 | 12/152 | Bracknell Forest
# MMR1 | 13/152 | Bradford
# MMR1 | 14/152 | Brent
# MMR1 | 15/152 | Brighton and Hove
# MMR1 | 16/152 | Bristol, City of
# MMR1 | 17/152 | Bromley
# MMR1 | 18/152 | Buckinghamshire
# MMR1 | 19/152 | Bury
# MMR1 | 20/152 | Calderdale
# MMR1 | 21/152 | Cambridgeshire
# MMR1 | 22/152 | Camden
# MMR1 | 23/152 | Central Bedfordshire
# MMR1 | 24/152 | Cheshire East
# MMR1 | 25/152 | Cheshire West and Chester
# MMR1 | 26/152 | Cornwall
# MMR1 | 27/152 | County Durham
# MMR1 | 28/152 | Coventry
# MMR1 | 29/152 | Croydon
# MMR1 | 30/152 | Cumberland
# MMR1 | 31/152 | Darlington
# MMR1 | 32/152 | Derby
# MMR1 | 33/152 | Derbyshire
# MMR1 | 34/152 | Devon
# MMR1 | 35/152 | Doncaster
# MMR1 | 36/152 | Dorset
# MMR1 | 37/152 | Dudley
# MMR1 | 38/152 | Ealing
# MMR1 | 39/152 | East Riding of Yorkshire
# MMR1 | 40/152 | East Sussex
# MMR1 | 41/152 | Enfield
# MMR1 | 42/152 | Essex
# MMR1 | 43/152 | Gateshead
# MMR1 | 44/152 | Gloucestershire
# MMR1 | 45/152 | Greenwich
# MMR1 | 46/152 | Hackney
# MMR1 | 47/152 | Halton
# MMR1 | 48/152 | Hammersmith and Fulham
# MMR1 | 49/152 | Hampshire
# MMR1 | 50/152 | Haringey
# MMR1 | 51/152 | Harrow
# MMR1 | 52/152 | Hartlepool
# MMR1 | 53/152 | Havering
# MMR1 | 54/152 | Herefordshire, County of
# MMR1 | 55/152 | Hertfordshire
# MMR1 | 56/152 | Hillingdon
# MMR1 | 57/152 | Hounslow
# MMR1 | 58/152 | Isle of Wight
# MMR1 | 59/152 | Islington
# MMR1 | 60/152 | Kensington and Chelsea
# MMR1 | 61/152 | Kent
# MMR1 | 62/152 | Kingston upon Hull, City of
# MMR1 | 63/152 | Kingston upon Thames
# MMR1 | 64/152 | Kirklees
# MMR1 | 65/152 | Knowsley
# MMR1 | 66/152 | Lambeth
# MMR1 | 67/152 | Lancashire
# MMR1 | 68/152 | Leeds
# MMR1 | 69/152 | Leicester
# MMR1 | 70/152 | Leicestershire
